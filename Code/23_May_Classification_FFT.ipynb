# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import glob
from scipy.io import loadmat

# %%
location = "C:/Users/alexc/OneDrive/Documents/Taiwan Classes/Second Semester/Brain Computer Interfaces/BCI Presentation and Project/SSVEP Projects/Wearable SSVEP BCI Database/Dataset/FFTs_from_matlab/"

files = glob.glob(location+"/*.mat")
files
# Out:
# ['C:/Users/alexc/OneDrive/Documents/Taiwan Classes/Second Semester/Brain Computer Interfaces/BCI Presentation and Project/SSVEP Projects/Wearable SSVEP BCI Database/Dataset/FFTs_from_matlab\\cleaned_S001.mat',
#  'C:/Users/alexc/OneDrive/Documents/Taiwan Classes/Second Semester/Brain Computer Interfaces/BCI Presentation and Project/SSVEP Projects/Wearable SSVEP BCI Database/Dataset/FFTs_from_matlab\\cleaned_S0010.mat',
#  'C:/Users/alexc/OneDrive/Documents/Taiwan Classes/Second Semester/Brain Computer Interfaces/BCI Presentation and Project/SSVEP Projects/Wearable SSVEP BCI Database/Dataset/FFTs_from_matlab\\cleaned_S002.mat',
#  'C:/Users/alexc/OneDrive/Documents/Taiwan Classes/Second Semester/Brain Computer Interfaces/BCI Presentation and Project/SSVEP Projects/Wearable SSVEP BCI Database/Dataset/FFTs_from_matlab\\cleaned_S003.mat',
#  'C:/Users/alexc/OneDrive/Documents/Taiwan Classes/Second Semester/Brain Computer Interfaces/BCI Presentation and Project/SSVEP Projects/Wearable SSVEP BCI Database/Dataset/FFTs_from_matlab\\cleaned_S004.mat',
#  'C:/Users/alexc/OneDrive/Documents/Taiwan Classes/Second Semester/Brain Computer Interfaces/BCI Presentation and Project/SSVEP Projects/Wearable SSVEP BCI Database/Dataset/FFTs_from_matlab\\cleaned_S005.mat',
#  'C:/Users/alexc/OneDrive/Documents/Taiwan Classes/Second Semester/Brain Computer Interfaces/BCI Presentation and Project/SSVEP Projects/Wearable SSVEP BCI Database/Dataset/FFTs_from_matlab\\cleaned_S006.mat',
#  'C:/Users/alexc/OneDrive/Documents/Taiwan Classes/Second Semester/Brain Computer Interfaces/BCI Presentation and Project/SSVEP Projects/Wearable SSVEP BCI Database/Dataset/FFTs_from_matlab\\cleaned_S007.mat',
#  'C:/Users/alexc/OneDrive/Documents/Taiwan Classes/Second Semester/Brain Computer Interfaces/BCI Presentation and Project/SSVEP Projects/Wearable SSVEP BCI Database/Dataset/FFTs_from_matlab\\cleaned_S008.mat',
#  'C:/Users/alexc/OneDrive/Documents/Taiwan Classes/Second Semester/Brain Computer Interfaces/BCI Presentation and Project/SSVEP Projects/Wearable SSVEP BCI Database/Dataset/FFTs_from_matlab\\cleaned_S009.mat']

# %%
#subjects = loadmat(files[0])  #for only 1 subject at a time

subjects = []

for file in files:
    subjects.append(loadmat(file))
subjects[0]
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: PCWIN64, Created on: Tue May 24 14:57:33 2022',
#  '__version__': '1.0',
#  '__globals__': [],
#  'fft_fir': array([[ 24.29266315,  19.48213606,   8.62434618, ..., -23.95641506,
#          -24.07171348, -25.72319523],
#         [ 13.98955519,  10.53884378,   4.35775745, ..., -32.90878499,
#          -29.10308578, -26.50364474],
#         [ 28.22633846,  22.92692172,  12.56838637, ..., -18.74202104,
#          -18.91035331, -16.05159439],
#         ...,
#         [ 10.27279605,   4.59735523,  -5.45843587, ..., -26.77976057,
#          -23.3180335 , -22.86545255],
#         [ 15.63061502,  10.85841567,   1.43425678, ..., -26.94581233,
#          -27.56018215, -24.60878901],
#         [  9.5292771 ,   3.7240898 ,  -8.36545176, ..., -26.96448216,
#          -22.91445671, -21.89520726]])}

# %%
data = []

for i in range(len(subjects)):
    data.append(subjects[i]['fft_fir'])

data = np.array(data)
data = data.reshape(-1,60)
print(data.shape)
data_df = pd.DataFrame(data)
# Out:
# (19200, 60)

# %%
data_df
# Out:
#               0          1          2         3          4          5   \
# 0      24.292663  19.482136   8.624346 -0.932498  -0.395269  -0.455120
# 1      13.989555  10.538844   4.357757 -4.671976  -2.448575  -0.195571
# 2      28.226338  22.926922  12.568386  5.334923   5.037145   4.942274
# 3      10.275999   4.947967  -2.816720 -0.592784   3.641866   4.649932
# 4      25.701159  19.995006   9.928850  2.699057   3.008508   3.815365
# ...          ...        ...        ...       ...        ...        ...
# 19195  21.179543  17.650708   8.669475  7.188492  10.143834  13.442618
# 19196  20.076919  16.466562  11.682462  8.845411   7.138819   9.722201
# 19197  18.305762  12.620668   4.046588  2.076714   3.060203   1.296164
# 19198  13.587028   7.778931   2.180232 -2.255587  -0.015129   1.644439
# 19199  24.779697  21.185264  11.010940 -1.571635  -0.244707  -3.424466
#
#               6          7          8          9   ...         50         51  \
# 0       0.855522   0.265530   0.903650   0.375534  ... -13.584742 -17.775369
# 1       0.800786   3.143261   5.239468   4.201113  ... -19.338698 -23.037337
# 2       5.231862   5.857457   4.706730   3.209744  ... -15.448929 -18.088635
# 3       2.646541  -1.270290  -2.929141  -6.799285  ... -23.264184 -25.827276
# 4       4.283556   5.071418   6.786370   5.908505  ...  -8.614429  -9.547422
# ...          ...        ...        ...        ...  ...        ...        ...
# 19195  14.552341  13.277050  10.922386   8.686466  ... -20.913449 -25.302469
# 19196  11.384334  10.624426   9.974557  10.918103  ... -12.957360 -18.564880
# 19197   2.429489   2.530325   2.279962  -1.639980  ... -15.742926 -17.418895
# 19198   1.219735   1.225475   0.336113   4.170542  ... -11.010249 -14.467469
# 19199  -2.214712  -3.602256  -2.660434  -5.058002  ... -18.330608 -20.029004
#
#               52         53         54         55         56         57  \
# 0     -23.828478 -29.688440 -27.825962 -28.735885 -25.563278 -23.956415
# 1     -24.662241 -26.398594 -29.188852 -32.163355 -33.288782 -32.908785
# 2     -18.498216 -20.343489 -24.681486 -22.983856 -19.623444 -18.742021
# 3     -29.137059 -33.401778 -34.409558 -38.743549 -33.571799 -31.196596
# 4     -10.940031 -13.318784 -17.843945 -22.670023 -23.983670 -22.243286
# ...          ...        ...        ...        ...        ...        ...
# 19195 -30.670637 -32.702324 -37.076804 -33.600102 -31.327253 -25.636348
# 19196 -22.590252 -21.795500 -25.755346 -26.822448 -26.784750 -24.527029
# 19197 -17.950836 -19.623803 -24.255326 -30.689708 -27.868408 -24.583183
# 19198 -20.759355 -27.619799 -30.522273 -31.144229 -31.162773 -30.041418
# 19199 -22.508731 -26.613126 -31.245265 -29.555480 -29.295782 -25.131930
#
#               58         59
# 0     -24.071713 -25.723195
# 1     -29.103086 -26.503645
# 2     -18.910353 -16.051594
# 3     -30.693376 -32.793738
# 4     -21.307530 -21.370648
# ...          ...        ...
# 19195 -22.255170 -22.006425
# 19196 -23.206505 -21.113754
# 19197 -21.633224 -22.130639
# 19198 -28.818501 -25.455148
# 19199 -22.422136 -22.454303
#
# [19200 rows x 60 columns]

# %%
N_subjects = len(subjects)
data_reshaped = data.reshape(8,240*N_subjects,60)
channel_data = np.zeros([8,240*N_subjects], dtype=object)

for i in range(8):
    for j in range(240*N_subjects):
        channel_data[i,j] = data_reshaped[i,j,:]

# %%
channel_data_df = pd.DataFrame(channel_data, index = ["POz", "PO3", "PO4", "PO5", "PO6", "Oz", "O1", "O2"])
final_df = channel_data_df.T

# %%
final_df["Target"] = np.NaN

# 20X12 = 240 trials in 1 subject. To do it for several subjects just mulptiply 20 x Number of subjects (since then it will be multiply x 12 targets)
for i in range(1,21*N_subjects):
        for j in range(12):
                index = (12*(i-1))
                final_df.Target.loc[index+j] = j+1
# Out:
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
pd.set_option('display.max_rows',10)
final_df
# Out:
#                                                     POz  \
# 0     [24.29266315341283, 19.48213606395432, 8.62434...
# 1     [13.98955518712934, 10.538843782048772, 4.3577...
# 2     [28.226338461279305, 22.926921715569048, 12.56...
# 3     [10.275999487881135, 4.947966663913328, -2.816...
# 4     [25.701159204059685, 19.99500644402103, 9.9288...
# ...                                                 ...
# 2395  [14.423508216291454, 7.549684666683326, -4.286...
# 2396  [19.46549474929658, 13.463798358018233, 7.5292...
# 2397  [19.584944854325226, 15.776929253217384, 9.668...
# 2398  [25.258435065917027, 21.045866216566363, 13.14...
# 2399  [18.015104986893828, 14.889707304409521, 8.060...
#
#                                                     PO3  \
# 0     [23.769096511995496, 18.933238277187304, 13.47...
# 1     [11.715272263947373, 5.623227058758493, -5.359...
# 2     [24.65597714364511, 20.680792973941884, 13.678...
# 3     [24.549596069488047, 21.715232304589875, 17.72...
# 4     [21.47701486490992, 14.918761284185585, 8.7073...
# ...                                                 ...
# 2395  [10.429627048340537, 2.9761053084523197, -7.55...
# 2396  [17.1615884959645, 11.786185723440088, 2.69639...
# 2397  [12.810112761269977, 6.094181411082745, 0.4891...
# 2398  [26.138181538650056, 21.880715694971194, 12.42...
# 2399  [6.48561194242864, 0.7353675947082985, -6.9821...
#
#                                                     PO4  \
# 0     [22.300975293317958, 18.254011593258063, 11.73...
# 1     [15.477873783703442, 11.843776357647567, 6.132...
# 2     [15.800124263807373, 9.43091086516514, 0.26076...
# 3     [13.616706509893058, 8.34303035696286, -0.1698...
# 4     [17.375144310289112, 12.994046887313381, 9.095...
# ...                                                 ...
# 2395  [12.578421156825577, 6.281074551793402, -0.156...
# 2396  [14.310191888016709, 7.119474600705655, -1.000...
# 2397  [12.16721229045016, 6.9821839684916105, 0.3003...
# 2398  [16.240387213443604, 11.249261240611318, 0.481...
# 2399  [12.663783641229918, 5.511110661323552, -7.142...
#
#                                                     PO5  \
# 0     [13.162641579207342, 5.352129881571881, -6.593...
# 1     [11.492562723071519, 8.114684634031669, 2.6195...
# 2     [10.92627352534915, 3.5408478277237525, -4.310...
# 3     [15.260579713070365, 9.125290023041009, -0.540...
# 4     [9.845058653349954, 1.3935732421413962, -12.21...
# ...                                                 ...
# 2395  [22.82301047519507, 19.3203925201207, 9.386902...
# 2396  [31.09142232465654, 27.68119374990978, 17.4763...
# 2397  [23.402525822144735, 19.972486254949985, 10.27...
# 2398  [31.303052962062743, 28.496207371250453, 20.56...
# 2399  [23.06805859501441, 18.986040799587162, 9.6189...
#
#                                                     PO6  \
# 0     [18.144057007645777, 14.125858143297103, 4.079...
# 1     [22.911395417185773, 19.733190938662684, 10.70...
# 2     [19.88741523989799, 15.333592514571112, 6.4170...
# 3     [8.63675131038874, 2.81699868909528, -5.486655...
# 4     [13.794869915453951, 9.231284004227724, 1.9321...
# ...                                                 ...
# 2395  [15.420349121613608, 11.198189874729946, 2.828...
# 2396  [14.502546276446488, 9.300420742355938, -1.845...
# 2397  [24.447224289145616, 21.440753972793587, 13.41...
# 2398  [7.978538797378186, 2.502167696399891, -3.6998...
# 2399  [11.95965011618895, 7.297536700853782, -3.8900...
#
#                                                      Oz  \
# 0     [25.006298568182512, 20.431140603706083, 8.823...
# 1     [15.014719789592055, 9.610374321872246, 2.5359...
# 2     [21.740911145886066, 16.870764587452655, 5.419...
# 3     [24.596287446193852, 21.309842945165947, 12.27...
# 4     [11.802127084791204, 5.661290934680356, -3.304...
# ...                                                 ...
# 2395  [6.199671142686048, 0.4419973423701159, -5.611...
# 2396  [18.232328472305042, 14.210245627578995, 4.476...
# 2397  [7.849004042888515, 1.4621951429444173, -5.636...
# 2398  [14.40742415455496, 10.335425901738345, -0.751...
# 2399  [8.073935965249346, 2.3180008202337223, -9.503...
#
#                                                      O1  \
# 0     [13.991918731515968, 8.01212040216852, -1.5774...
# 1     [5.781238853865486, -1.6716148170641856, -10.1...
# 2     [14.786373873810525, 8.548591196267271, -4.098...
# 3     [6.069454395905265, 0.49229160635844904, -9.87...
# 4     [17.374820645125077, 13.266751502137133, 2.831...
# ...                                                 ...
# 2395  [12.177749915900424, 5.297118537794736, -5.929...
# 2396  [13.558441495153822, 6.869831188001572, 0.0220...
# 2397  [17.595196944085444, 11.318247161615158, 2.422...
# 2398  [19.751572697732993, 15.536166916948916, 10.05...
# 2399  [25.153086590748764, 21.74395710413515, 11.891...
#
#                                                      O2  Target
# 0     [20.674892650297583, 17.624733209611946, 12.89...     1.0
# 1     [13.908425819511395, 6.507044263130492, -7.163...     2.0
# 2     [26.871527396757116, 24.808975944586773, 19.15...     3.0
# 3     [16.809018188511548, 13.192449157213042, 5.129...     4.0
# 4     [19.77945943760399, 17.419582793228287, 12.353...     5.0
# ...                                                 ...     ...
# 2395  [21.179542719902464, 17.650708407157126, 8.669...     8.0
# 2396  [20.076919101131406, 16.466562449081643, 11.68...     9.0
# 2397  [18.305762333692904, 12.620667633334227, 4.046...    10.0
# 2398  [13.58702814078097, 7.778930534778753, 2.18023...    11.0
# 2399  [24.779696847159894, 21.18526405755365, 11.010...    12.0
#
# [2400 rows x 9 columns]
